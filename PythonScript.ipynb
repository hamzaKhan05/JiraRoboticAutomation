# %%
import pandas as pd
df=pd.read_csv("23ARelease_Bugs_Netsol (Jira) 2023-08-01T13_47_34+0800.csv")
df.to_csv("23ARelease_Bugs_Netsol (Jira) 2023-08-01T13_47_34+0800.csv",index=None)

# %%
df
# Out:
#                                               Summary    Issue key  Issue id  \
# 0   MY DAAS -  Submitted request not reflecting in...  ASDTM-11510    303168
# 1                   MY: Incorrect master data mapping  ASDTM-11509    303151
# 2   Contract number wrongly capturing at receiptin...  ASDTM-11507    303118
# 3   CMS-WFS Model D I Netting-off Incorrect Behaviour  ASDTM-11506    303117
# 4                          Mobile Number update issue  ASDTM-11504    303110
# 5   Remarketing related accounting entries are not...  ASDTM-11503    303090
# 6   During Restructure of TDS contract in NEW mock...  ASDTM-11502    303088
# 7   CMS-SAP Model D I VAN is not reflected in OTV ...  ASDTM-11498    303002
# 8   CMS-SAP Model D I Payable Charges with wrong M...  ASDTM-11497    303001
# 9   MY POS-CMS: Installment Amount changing to 0 o...  ASDTM-11496    302996
# 10           FMO slowness - CSI and Task Queue Retail  ASDTM-11463    302609
# ...

# %%
status={'Open'}
cols=df.columns

# %%
cols
# Out:
# Index(['Summary', 'Issue key', 'Issue id', 'Issue Type', 'Status',
#        'Project key', 'Project name', 'Project type', 'Project lead',
#        'Project description',
#        ...
#        'Comment.18', 'Comment.19', 'Comment.20', 'Comment.21', 'Comment.22',
#        'Comment.23', 'Comment.24', 'Comment.25', 'Comment.26', 'Comment.27'],
#       dtype='object', length=420)

# %%
df_final=pd.DataFrame(columns=cols)
row=pd.Series()
for i in status:
    row=df[df['Status']==f'i']
    df_final=pd.concat([df_final,row.to_frame])
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_8740\2039430638.py:2: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   row=pd.Series()

# %%
df_final
# Out:
# Empty DataFrame
# ...
